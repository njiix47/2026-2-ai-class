# %%
print("Hello")
# Out:
# Hello

# %%
f = open('name.txt', 'r', encoding='utf-8')
data = f.read()

print(data)
f.close()
# Out:
# 토트넘
# PSG
# 바이에른 뮌헨
# 울버햄튼

# %%
f = open('name2.txt', 'w', encoding='utf-8')

while True :
    team = input() 

    if not team :
        break

    f.write(team + '\n')

f.close()
